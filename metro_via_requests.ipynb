# %%
import requests

# %%
URL = 'https://ru.wikipedia.org/wiki/Список_станций_Московского_метрополитена'

# %%
html_page = requests.get(URL)

# %%
import pandas as pd

# %%
pd.read_html(html_page.content, attrs={'class': 'standard sortable'})[0].head(10)
# Out:
#    Unnamed: 0                   Название станцииПрежние названия  \
# 0         NaN  Бульвар РокоссовскогоУлица Подбельского (до 2014)
# 1         NaN                                       Черкизовская
# 2         NaN                             Преображенская площадь
# 3         NaN                                         Сокольники
# 4         NaN                                     Красносельская
# 5         NaN                                      Комсомольская
# 6         NaN       Красные ВоротаЛермонтовская (с 1962 до 1986)
# 7         NaN                    Чистые прудыКировская (до 1990)
# 8         NaN                       ЛубянкаДзержинская (до 1990)
# 9         NaN  Охотный РядИмени Л. М. Кагановича(с 1955 до 19...
#
#       Датаоткрытия  Пере-садки Глубина,м[2]  \
# 0   1 августа 1990         NaN           −8
# 1   1 августа 1990         NaN           −9
# 2  31 декабря 1965         NaN           −8
# 3      15 мая 1935         NaN           −9
# ...
